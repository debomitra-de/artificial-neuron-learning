# %%
import numpy as np
import pandas as pd

data=pd.read_csv("Finaldataset.csv")

# %%
data
# Out:
#            Date      Open      High       Low     Close  \
# 0     26-May-20  30864.27  31086.70  30512.14  30609.30
# 1     22-May-20  30822.78  31107.91  30474.88  30672.59
# 2     21-May-20  30904.29  31188.79  30765.32  30932.90
# 3     20-May-20  30159.59  30878.31  30157.75  30818.61
# 4     19-May-20  30450.74  30739.96  30116.82  30196.17
# ...         ...       ...       ...       ...       ...
# 2065  06-Jan-12  15789.08  16001.31  15664.91  15867.73
# 2066  05-Jan-12  15893.07  15980.17  15809.31  15857.08
# 2067  04-Jan-12  15967.49  16004.69  15822.32  15882.64
# 2068  03-Jan-12  15640.56  15970.31  15640.56  15939.36
# 2069  02-Jan-12  15534.67  15542.85  15358.02  15517.92
#
#                                                   Title
# 0     ATMs to become virtual bank branches, accept d...
# 1     Retail, MSME loans to get cheaper as RBI cuts ...
# 2     Covid-19: Banking slippages may rise by Rs 5.5...
# 3     Govt to use RBI money to support struggling NB...
# 4     PSBs report sharp rise in deposits thanks to Y...
# ...                                                 ...
# 2065                                                NaN
# 2066                                                NaN
# 2067                                                NaN
# 2068                                                NaN
# 2069                                                NaN
#
# [2070 rows x 6 columns]

# %%
data.drop("Date",axis=1,inplace=True)
data.drop("Title",axis=1,inplace=True)

# %%
import matplotlib.pyplot as mp
import seaborn as sb

dataplot=sb.heatmap(data.corr(),cmap="Blues",annot=True)

mp.show()

# %%
x = data.drop("Close",axis=1)
y = data.drop(["Low","High","Open"],axis=1)

# %%
x
# Out:
#           Open      High       Low
# 0     30864.27  31086.70  30512.14
# 1     30822.78  31107.91  30474.88
# 2     30904.29  31188.79  30765.32
# 3     30159.59  30878.31  30157.75
# 4     30450.74  30739.96  30116.82
# ...        ...       ...       ...
# 2065  15789.08  16001.31  15664.91
# 2066  15893.07  15980.17  15809.31
# 2067  15967.49  16004.69  15822.32
# 2068  15640.56  15970.31  15640.56
# 2069  15534.67  15542.85  15358.02
#
# [2070 rows x 3 columns]

# %%
y
# Out:
#          Close
# 0     30609.30
# 1     30672.59
# 2     30932.90
# 3     30818.61
# 4     30196.17
# ...        ...
# 2065  15867.73
# 2066  15857.08
# 2067  15882.64
# 2068  15939.36
# 2069  15517.92
#
# [2070 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split  

x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= .3)
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()
regressor.fit(x_train, y_train)
y_pred=regressor.predict(x_test)

from sklearn.metrics import mean_squared_error, r2_score
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)

print("Mean Squared Error:",mse)
print("R2 Score:",r2)
# Out:
# Mean Squared Error: 8044.8001146850565
# R2 Score: 0.9998425112508852
